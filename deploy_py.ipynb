# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumathi-G/Data_scientist/blob/main/deploy_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import streamlit as st
import pandas as pd
import numpy as np
import pickle

# -------------------------------------------------
# Page Configuration
# -------------------------------------------------
st.set_page_config(
    page_title="ML Model Deployment",
    page_icon="🤖",
    layout="centered"
)

# -------------------------------------------------
# Title & Description
# -------------------------------------------------
st.title("🤖 Machine Learning Web App")
st.markdown("A simple Streamlit frontend for model deployment")

# -------------------------------------------------
# Load Model (Optional)
# -------------------------------------------------
@st.cache_resource
def load_model():
    # Replace with your model file
    # model = pickle.load(open("model.pkl", "rb"))
    model = None
    return model

model = load_model()

# -------------------------------------------------
# Sidebar Inputs
# -------------------------------------------------
st.sidebar.header("Input Features")

age = st.sidebar.slider("Age", 18, 65, 30)
salary = st.sidebar.number_input("Estimated Salary", min_value=1000, max_value=200000, step=1000)

# -------------------------------------------------
# Input DataFrame
# -------------------------------------------------
input_data = pd.DataFrame({
    "Age": [age],
    "EstimatedSalary": [salary]
})

st.subheader("User Input Data")
st.write(input_data)

# -------------------------------------------------
# Prediction Section
# -------------------------------------------------
if st.button("Predict"):
    if model is not None:
        prediction = model.predict(input_data)
        st.success(f"Prediction Result: {prediction[0]}")
    else:
        st.warning("⚠️ Model not loaded. Add your trained model.pkl file.")

# -------------------------------------------------
# Optional: File Upload
# -------------------------------------------------
st.subheader("/content/Social_Network_Ads.csv")
uploaded_file = st.file_uploader("/content/Social_Network_Ads.csv", type=["csv"])

if uploaded_file:
    df = pd.read_csv(uploaded_file)
    st.write("/content/Social_Network_Ads.csv")
    st.dataframe(df.head())

# -------------------------------------------------
# Footer
# -------------------------------------------------
st.markdown("---")
st.markdown("Developed with ❤️ using **Streamlit**")
# Out:
# 2025-12-18 10:21:47.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 10:21:47.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 10:21:47.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 10:21:47.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 10:21:47.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 10:21:47.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 10:21:47.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
